# %%
# !pip install flask-ngrok
# !pip install pyvi
# !pip install underthesea
# Out:
# ...
#      |████████████████████████████████| 8.5MB 21.2MB/s
# ...
#      |████████████████████████████████| 747kB 29.8MB/s
# ...
#      |████████████████████████████████| 7.5MB 20.2MB/s
# ...
#      |████████████████████████████████| 1.3MB 31.3MB/s
# ...
#      |████████████████████████████████| 245kB 41.3MB/s
# ...
#      |████████████████████████████████| 753.2MB 21kB/s
# ...
#      |████████████████████████████████| 51kB 4.5MB/s
# ...
#      |████████████████████████████████| 1.1MB 40.9MB/s
# ...
#      |████████████████████████████████| 2.9MB 30.1MB/s
# ...
#      |████████████████████████████████| 901kB 48.7MB/s
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp37-none-any.whl size=16172 sha256=8404c0658ab463e10cfa5255d8ec51d0cc9628b564f03ae7dcc4d69e8928072e
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
# Successfully built seqeval
# ERROR: torchvision 0.9.1+cu101 has requirement torch==1.8.1, but you'll have torch 1.5.1 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cp -av "/content/gdrive/My Drive/Khoa Luan/AppFlask" "/content/"
# Out:
# Mounted at /content/gdrive
# '/content/gdrive/My Drive/Khoa Luan/AppFlask' -> '/content/AppFlask'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/server.py' -> '/content/AppFlask/server.py'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/templates' -> '/content/AppFlask/templates'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/templates/dulieu.html' -> '/content/AppFlask/templates/dulieu.html'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/templates/result.html' -> '/content/AppFlask/templates/result.html'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/templates/ketqua.html' -> '/content/AppFlask/templates/ketqua.html'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/templates/home.html' -> '/content/AppFlask/templates/home.html'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/pickle' -> '/content/AppFlask/pickle'
# '/content/gdrive/My Drive/Khoa Luan/AppFlask/pickle/word2idx.pickle' -> '/content/AppFlask/pickle/word2idx.pickle'
# ...

# %%
# %cd AppFlask
# !ls
# Out:
# /content/AppFlask
# appFlask.ipynb	pickle	server.py  static  templates

# %%
# !python server.py
# Out:
# 2021-05-18 05:32:26.768785: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-18 05:32:29.799377: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-18 05:32:29.815854: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-18 05:32:29.828834: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-05-18 05:32:29.828919: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c2db2f6294d7): /proc/driver/nvidia/version does not exist
# 2021-05-18 05:32:29.832883: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
#  * Serving Flask app "server" (lazy loading)
# ...
